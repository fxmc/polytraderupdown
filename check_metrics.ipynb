# %%
import polars as pl

df = pl.read_ndjson(r"C:\Users\ccodi\Documents\prog\python\polytraderupdown\logs\run_20260201_221712\metrics.jsonl")

# %%
book = df.filter(pl.col("type") == "book_1s")
fv   = df.filter(pl.col("type") == "fv_vol_1s")

# %%
fv.to_pandas().to_clipboard(excel=True)
